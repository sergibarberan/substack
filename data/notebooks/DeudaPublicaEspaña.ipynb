# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib.patheffects as path_effects
import highlight_text as htext
import matplotlib.ticker as mtick
from highlight_text import ax_text, fig_text

# %%
title_font = "Proxima Nova"
body_font = "Proxima Nova"
text_color = "k"
subtitle_color="dimgray"
notes_color='gray'
series1 = "teal"
series2 = "mediumspringgreen"
series3 = "lightgrey"
series4 = "peru"
series5 = 'gold'
series6 = 'navajowhite'
background = "white"
edgecolor = 'white'

#definimos la plantilla de matplotlib

mpl.rcParams['xtick.color'] = text_color
mpl.rcParams['ytick.color'] = text_color
mpl.rcParams['xtick.labelsize'] = 10
mpl.rcParams['ytick.labelsize'] = 10

#creamos la figura y le damos tamaño

fig, ax = plt.subplots(figsize=(9,5))
fig.set_facecolor(background)
ax.patch.set_alpha(0)
ax.grid(ls="dotted",lw="0.5",color="lightgrey", zorder=0)

#graficamos las variables

plt.bar(data.Country,data.ForeignOfficial,edgecolor=edgecolor,lw=1,color=series1,zorder=2,label='Extranjeros, entes públicos')
plt.bar(data.Country,data.ForeignBank,edgecolor=edgecolor,lw=1,color=series2,bottom=data.ForeignOfficial,zorder=2,label='Extranjeros, bancos')
plt.bar(data.Country,data.ForeignNonBank,edgecolor=edgecolor,lw=1,color=series3,bottom=data.ForeignOfficial+data.ForeignBank,zorder=2,label='Extranjeros, otros')
plt.bar(data.Country,data.DomesticCB,edgecolor=edgecolor,lw=1,color=series4,bottom=data.ForeignOfficial+data.ForeignBank+data.ForeignNonBank,zorder=2,label='Nacionales, BC')
plt.bar(data.Country,data.DomesticBank,edgecolor=edgecolor,lw=1,color=series5,bottom=data.ForeignOfficial+data.ForeignBank+data.ForeignNonBank+data.DomesticCB,zorder=2,label='Nacionales, bancos')
plt.bar(data.Country,data.DomesticNonBank,edgecolor=edgecolor,lw=1,color=series6,bottom=data.ForeignOfficial+data.ForeignBank+data.ForeignNonBank+data.DomesticCB+data.DomesticBank,zorder=2,label='Nacionales, otros')

#eliminamos los bordes correspondientes

spines = ["top","right","bottom","left"]
for s in spines:
    if s in ["top","right","bottom","left"]:
        ax.spines[s].set_visible(False)
    else:
        ax.spines[s].set_color(text_color)

#damos nombre y formato a los ejes del gráfico

ax.set_ylabel("Porcentaje del total de deuda", fontfamily=title_font, fontweight="bold", fontsize= 13, color=text_color)
ax.tick_params(axis="both",length=0)
plt.xticks(fontsize=13,fontname=body_font)
plt.yticks(fontsize=12,fontname=body_font)
ax.yaxis.set_major_formatter(mtick.PercentFormatter(xmax=1))

#añadimos leyenda

mpl.rc('font',family='Proxima Nova')
plt.legend(frameon=True,fontsize=12,ncol=3,loc=2,bbox_to_anchor=(-0.03, 1.135),facecolor='w',edgecolor='w',framealpha=.6)

#ponemos título, subtítulo y anotaciones al gráfico

fig_text(x=0.045,y=1.03,s='Porcentaje de la deuda pública nacional en manos de tenedores \nextranjeros y domésticos',color = 'k',fontname=title_font,fontsize=18,fontweight='bold')
fig.text(0.045,.985,"Un alto porcentaje de la deuda pública española está en manos extranjeras",fontweight="regular", fontsize=15,fontfamily=body_font, color=subtitle_color)
fig.text(0.045,0,"Datos procedentes de la Sovereign Debt Investor Base for Advanced Economies (FMI). Información a \ncierre de 2019 para evitar sesgos interpretativos. @sergibarberan.",fontweight="regular", fontsize=12,fontfamily=body_font, color=notes_color)

# %%
title_font = "Proxima Nova"
body_font = "Proxima Nova"
text_color = "k"
subtitle_color="dimgray"
notes_color='gray'
series1 = "teal"
series2 = "mediumspringgreen"
series3 = "lightgrey"
series4 = "peru"
series5 = 'gold'
series6 = 'navajowhite'
background = "white"
edgecolor = 'white'

#definimos la plantilla de matplotlib

mpl.rcParams['xtick.color'] = text_color
mpl.rcParams['ytick.color'] = text_color
mpl.rcParams['xtick.labelsize'] = 10
mpl.rcParams['ytick.labelsize'] = 10

#creamos la figura y le damos tamaño

fig, ax = plt.subplots(figsize=(9,5))
fig.set_facecolor(background)
ax.patch.set_alpha(0)
ax.grid(ls="dotted",lw="0.5",color="lightgrey", zorder=0)

#graficamos las variables

plt.stackplot(data.Quarter,data.ForeignOfficialTS,data.ForeignBankTS,data.ForeignNonBankTS,data.DomesticCBTS,data.DomesticBankTS,data.DomesticNonBankTS,edgecolor=edgecolor,lw=1,colors=[series1,series2,series3,series4,series5,series6],zorder=2,labels=['Extranjeros, entes públicos','Extranjeros, bancos','Extranjeros, otros','Nacionales, BC','Nacionales, bancos','Nacionales, otros'])

#eliminamos los bordes correspondientes

spines = ["top","right","bottom","left"]
for s in spines:
    if s in ["top","right","bottom","left"]:
        ax.spines[s].set_visible(False)
    else:
        ax.spines[s].set_color(text_color)

#damos nombre y formato a los ejes del gráfico

ax.set_ylabel("Porcentaje del total de deuda", fontfamily=title_font, fontweight="bold", fontsize= 13, color=text_color)
ax.tick_params(axis="both",length=0)
plt.xticks(fontsize=12,fontname=body_font)
plt.yticks(fontsize=12,fontname=body_font)
ax.yaxis.set_major_formatter(mtick.PercentFormatter(xmax=1))
plt.margins(x=0)

#añadimos leyenda

mpl.rc('font',family='Proxima Nova')
plt.legend(frameon=True,fontsize=12,ncol=3,loc=2,bbox_to_anchor=(-0.03, 1.135),facecolor='w',edgecolor='w',framealpha=.6)

#ponemos título, subtítulo y anotaciones al gráfico

fig_text(x=0.045,y=1.03,s='Evolución del porcentaje de deuda nacional controlada por grupos \nde tenedores en el periodo 2004-2020',color = 'k',fontname=title_font,fontsize=18,fontweight='bold')
fig.text(0.045,.985,"Los inversores privados extranjeros y el BCE, los actuales señores de la deuda",fontweight="regular", fontsize=15,fontfamily=body_font, color=subtitle_color)
fig.text(0.045,0,"Datos procedentes de la Sovereign Debt Investor Base for Advanced Economies (FMI). Incluye información \nde los 3 primeros trimestres de 2020. @sergibarberan.",fontweight="regular", fontsize=12,fontfamily=body_font, color=notes_color)

# %%
title_font = "Proxima Nova"
body_font = "Proxima Nova"
text_color = "k"
subtitle_color="dimgray"
notes_color='gray'
series1 = "#ce6a6b"
series2 = "#ebaca2"
series3 = "#bed3c3"
series4 = "#4a919e"
background = "white"
edgecolor = 'white'

#definimos la plantilla de matplotlib

mpl.rcParams['xtick.color'] = text_color
mpl.rcParams['ytick.color'] = text_color
mpl.rcParams['xtick.labelsize'] = 10
mpl.rcParams['ytick.labelsize'] = 10

#creamos la figura y le damos tamaño

fig, ax = plt.subplots(figsize=(9,5))
fig.set_facecolor(background)
ax.patch.set_alpha(0)
ax.grid(ls="dotted",lw="0.5",color="lightgrey", zorder=0)

#graficamos las variables

plt.bar(data.Trimestre,data.AACC,color=series1,edgecolor=edgecolor,zorder=2,label='Gobierno central', width=.9)
plt.bar(data.Trimestre,data.CCAA,bottom=data.AACC,color=series2,edgecolor=edgecolor,zorder=2,label='CCAA', width=.9)
plt.bar(data.Trimestre,data.CCLL,bottom=data.AACC+data.CCAA,color=series3,edgecolor=edgecolor,zorder=2,label='CCLL', width=.9)
plt.bar(data.Trimestre,data.SS,color=series4,edgecolor=edgecolor,zorder=1,label='Seguridad Social', width=.9)

#eliminamos los bordes correspondientes

spines = ["top","right","bottom","left"]
for s in spines:
    if s in ["top","right","bottom","left"]:
        ax.spines[s].set_visible(False)
    else:
        ax.spines[s].set_color(text_color)

#damos nombre y formato a los ejes del gráfico

ax.set_ylabel("Porcentaje del PIB", fontfamily=title_font, fontweight="bold", fontsize= 13, color=text_color)
ax.tick_params(axis="both",length=0)
plt.xticks(fontsize=12,fontname=body_font)
plt.yticks(fontsize=12,fontname=body_font)
ax.yaxis.set_major_formatter(mtick.PercentFormatter(xmax=100))

#añadimos otros elementos

plt.axhline(y=100,lw=.5,c='dimgray',linestyle='--')

#ponemos título, subtítulo y anotaciones al gráfico

fig_text(x=0.045,y=.965,s='Porcentaje de deuda sobre PIB de las administraciones <central>, \n<autonómica>, <local> y la <Seguridad Social>, años 1995-2020',highlight_colors=[series1,series2,series3,series4],highlight_weights=['bold'],fontname=title_font,fontsize=18,fontweight='bold')
fig.text(0.045,.92,"España no ha aprovechado los años de crecimiento para ajustar sus cuentas",fontweight="regular", fontsize=15,fontfamily=body_font, color=subtitle_color)
fig.text(0.045,0,"Datos extraídos de las Estadísticas del Banco de España. Cifras correspondientes al T4 de cada año \nexcepto para 2020, cuya serie termina en el T3. @sergibarberan.",fontweight="regular", fontsize=12,fontfamily=body_font, color=notes_color)

# %%
title_font = "Proxima Nova"
body_font = "Proxima Nova"
text_color = "k"
subtitle_color="dimgray"
notes_color='gray'
series1 = "gold"
series2 = "#f3a67c"
series3 = "mediumaquamarine"
background = "white"
edgecolor = 'white'

#definimos la plantilla de matplotlib

mpl.rcParams['xtick.color'] = text_color
mpl.rcParams['ytick.color'] = text_color
mpl.rcParams['xtick.labelsize'] = 10
mpl.rcParams['ytick.labelsize'] = 10

#creamos la figura y le damos tamaño

fig, ax = plt.subplots(figsize=(9,5))
fig.set_facecolor(background)
ax.patch.set_alpha(0)
ax.grid(ls="dotted",lw="0.5",color="lightgrey", zorder=0)

#graficamos las variables

plt.plot(data.Year,data.Letras,color=series1,lw=2.5)
plt.plot(data.Year,data.Bonos,color=series2,lw=2.5)
plt.plot(data.Year,data.Obligaciones,color=series3,lw=2.5)

#eliminamos los bordes correspondientes

spines = ["top","right","bottom","left"]
for s in spines:
    if s in ["top","right","bottom","left"]:
        ax.spines[s].set_visible(False)
    else:
        ax.spines[s].set_color(text_color)

#damos nombre y formato a los ejes del gráfico

ax.set_ylabel("Tipo de interés", fontfamily=title_font, fontweight="bold", fontsize= 13, color=text_color)
ax.tick_params(axis="both",length=0)
plt.xticks(fontsize=12,fontname=body_font)
plt.yticks(fontsize=12,fontname=body_font)
ax.yaxis.set_major_formatter(mtick.PercentFormatter(xmax=100))

#añadimos otros elementos

plt.axhline(y=0,lw=.5,linestyle='--',c='dimgray')
plt.xticks(np.arange(start=2002, stop=2022, step=2))

#ponemos título, subtítulo y anotaciones al gráfico

fig_text(x=0.045,y=.965,s='Tipo de interés medio de <letras>, <bonos> y <obligaciones> del Estado en \ncirculación, periodo 2002-2020',highlight_colors=[series1,series2,series3],highlight_weights=['bold'],fontname=title_font,fontsize=18,fontweight='bold')
fig.text(0.045,.92,"Las intervenciones del BCE desde 2012 han llevado los tipos a mínimos históricos",fontweight="regular", fontsize=15,fontfamily=body_font, color=subtitle_color)
fig.text(0.045,0.04,"Datos procedentes del Informe del Tesoro Público. Tipos medios a cierre de año. @sergibarberan.",fontweight="regular", fontsize=12,fontfamily=body_font, color=notes_color)

# %%
title_font = "Proxima Nova"
body_font = "Proxima Nova"
text_color = "k"
subtitle_color="dimgray"
notes_color='gray'
series4 = "#ffdb3c"
series2 = "#dbf6e9"
series3 = "#9ddfd3"
series1 = "#31326f"
background = "white"
edgecolor = 'white'

#definimos la plantilla de matplotlib

mpl.rcParams['xtick.color'] = text_color
mpl.rcParams['ytick.color'] = text_color
mpl.rcParams['xtick.labelsize'] = 10
mpl.rcParams['ytick.labelsize'] = 10

#creamos la figura y le damos tamaño

fig, ax = plt.subplots(figsize=(9,5))
fig.set_facecolor(background)
ax.patch.set_alpha(0)
ax.grid(ls="dotted",lw="0.5",color="lightgrey", zorder=0)

#graficamos las variables

plt.bar(data.Anno,data.Governments,color=series1,edgecolor=edgecolor,zorder=2,label='Amortizaciones')
plt.bar(data.Anno,data.Loans,bottom=data.Governments,color=series2,edgecolor=edgecolor,zorder=2,label='Préstamos')
plt.bar(data.Anno,data.Interest,bottom=data.Governments+data.Loans,color=series3,edgecolor=edgecolor,zorder=2,label='Intereses')
plt.bar(data.Anno,data.Amount,bottom=data.Governments+data.Loans+data.Interest,color=series4,edgecolor=edgecolor,zorder=2,label='Otros compromisos')

#eliminamos los bordes correspondientes

spines = ["top","right","bottom","left"]
for s in spines:
    if s in ["top","right","bottom","left"]:
        ax.spines[s].set_visible(False)
    else:
        ax.spines[s].set_color(text_color)

#damos nombre y formato a los ejes del gráfico

ax.set_ylabel("Millones de euros", fontfamily=title_font, fontweight="bold", fontsize= 13, color=text_color)
ax.tick_params(axis="both",length=0)
plt.xticks(fontsize=12,fontname=body_font)
plt.yticks(fontsize=12,fontname=body_font)
ax.get_yaxis().set_major_formatter(mpl.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))


#añadimos otros elementos

plt.axhline(y=100,lw=.5,c='dimgray',linestyle='--')

#añadimos leyenda

mpl.rc('font',family='Proxima Nova')
plt.legend(frameon=True,fontsize=12,ncol=4,loc=2,bbox_to_anchor=(-0.03, 1.11),facecolor='w',edgecolor='w',framealpha=.6)

#ponemos título, subtítulo y anotaciones al gráfico

fig_text(x=0.045,y=1,s='Perfil de vencimientos anuales de la deuda pública española',fontname=title_font,fontsize=18,fontweight='bold')
fig.text(0.045,.955,"España enfrentará está década importantes pagos de intereses y vencimientos",fontweight="regular", fontsize=15,fontfamily=body_font, color=subtitle_color)
fig.text(0.045,0,"Datos obtenidos de Bloomberg y el Tesoro Público, correspondientes a cierre de 2020. Se muestran \ntanto principales como intereses de la deuda. 2051 recoge de dicho año en adelante. @sergibarberan.",fontweight="regular", fontsize=12,fontfamily=body_font, color=notes_color)

# %%
title_font = "Proxima Nova"
body_font = "Proxima Nova"
text_color = "k"
subtitle_color="dimgray"
notes_color='gray'
series1 = "turquoise"
series2 = "mediumpurple"
background = "white"
edgecolor = 'white'

#definimos la plantilla de matplotlib

mpl.rcParams['xtick.color'] = text_color
mpl.rcParams['ytick.color'] = text_color
mpl.rcParams['xtick.labelsize'] = 10
mpl.rcParams['ytick.labelsize'] = 10

#creamos la figura y le damos tamaño

fig, ax = plt.subplots(figsize=(9,5))
fig.set_facecolor(background)
ax.patch.set_alpha(0)
ax.grid(ls="dotted",lw="0.5",color="lightgrey", zorder=0)

#graficamos las variables

plt.plot(data.Any,data.Deuda,color=series2,lw=2.5)
plt.plot(data.Any,data.Interes,color=series1,lw=2.5)

#eliminamos los bordes correspondientes

spines = ["top","right","bottom","left"]
for s in spines:
    if s in ["top","right","bottom","left"]:
        ax.spines[s].set_visible(False)
    else:
        ax.spines[s].set_color(text_color)

#damos nombre y formato a los ejes del gráfico

ax.set_ylabel("Índice Base 2000", fontfamily=title_font, fontweight="bold", fontsize= 13, color=text_color)
ax.tick_params(axis="both",length=0)
plt.xticks(fontsize=12,fontname=body_font)
plt.yticks(fontsize=12,fontname=body_font)

#añadimos otros elementos

plt.axhline(y=100,lw=.5,linestyle='--',c='dimgray')
plt.xticks(np.arange(start=2000, stop=2020, step=2))

#ponemos título, subtítulo y anotaciones al gráfico

fig_text(x=0.045,y=.965,s='Ratio sobre PIB de la <deuda pública> y el <pago de intereses> para el \nperiodo 2000-2019, con base año 2000',highlight_colors=[series2,series1],highlight_weights=['bold'],fontname=title_font,fontsize=18,fontweight='bold')
fig.text(0.045,.92,"Pese a su mayor deuda, España paga hoy menos intereses que en el año 2000",fontweight="regular", fontsize=15,fontfamily=body_font, color=subtitle_color)
fig.text(0.045,0,"Datos procedentes del Informe del Tesoro Público. Variables sin deflactar. Índices calculados en base al \nPIB nominal de cada año. @sergibarberan.",fontweight="regular", fontsize=12,fontfamily=body_font, color=notes_color)
